# %% [markdown]
# <a href="https://colab.research.google.com/github/Jannat1803/PIMA-Indian-Dataset/blob/main/PIMA_Indian_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import metrics
from sklearn.metrics import recall_score
from imblearn.over_sampling import SMOTE

# %%
#Reading the dataset
pima_df = pd.read_csv("diabetes.csv")
pima_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
pima_df[~pima_df.applymap(np.isreal).all(1)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# replace the missing values in pima_df with median value
pima_df = pima_df.fillna(pima_df.median())
pima_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# analyzing the distribution of the various attributes
pima_df.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
pima_df.groupby(["Outcome"]).count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                500      500            500            500      500  500
# 1                268      268            268            268      268  268
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             500  500
# 1                             268  268

# %%
array = pima_df.values
X = array[:,0:7]
Y = array[:,8]
test_size = 0.25
seed = 7
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)
# type(X_train)
type(y_train)
# type(X_train)
# type(X_train)
# Out:
# numpy.ndarray

# %% [markdown]
# SMOTE to Upsampling smaller class

# %%
print("Before UpSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before UpSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(sampling_strategy = 1 ,k_neighbors = 5, random_state=1)   #Synthetic Minority Over Sampling Technique
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())


print("After UpSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After UpSampling, counts of label '0': {} \n".format(sum(y_train_res==0)))



print('After UpSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train_res.shape))
# Out:
# Before UpSampling, counts of label '1': 198
# Before UpSampling, counts of label '0': 378
#
# After UpSampling, counts of label '1': 378
# After UpSampling, counts of label '0': 378
#
# After UpSampling, the shape of train_X: (756, 7)
# After UpSampling, the shape of train_y: (756,)

# %%
# Fit the model on original data i.e. before upsampling

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
model_score = model.score(X_test, y_test)
print(model_score)
# Out:
# 0.3143823887587823

# %%
test_pred = model.predict(X_test).round()

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,test_pred)
print("Accuracy = ",accuracy)

print(metrics.classification_report(y_test, test_pred))
print(metrics.confusion_matrix(y_test, test_pred))
# Out:
# Accuracy =  0.7708333333333334
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.88      0.83       122
#          1.0       0.73      0.59      0.65        70
#
#     accuracy                           0.77       192
#    macro avg       0.76      0.73      0.74       192
# weighted avg       0.77      0.77      0.76       192
#
# [[107  15]
#  [ 29  41]]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
model_score = model.score(X_test, y_test)
print(model_score)
# Out:
# 0.7604166666666666

# %%
test_pred = model.predict(X_test).round()

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,test_pred)
print("Accuracy = ",accuracy)

print(metrics.classification_report(y_test, test_pred))
print(metrics.confusion_matrix(y_test, test_pred))
# Out:
# Accuracy =  0.7604166666666666
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.87      0.82       122
#          1.0       0.71      0.57      0.63        70
#
#     accuracy                           0.76       192
#    macro avg       0.75      0.72      0.73       192
# weighted avg       0.76      0.76      0.75       192
#
# [[106  16]
#  [ 30  40]]

# %% [markdown]
# **Extra Tree Classifier**

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
from sklearn.metrics import classification_report
pred = etc.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82       122
#          1.0       0.74      0.50      0.60        70
#
#     accuracy                           0.76       192
#    macro avg       0.75      0.70      0.71       192
# weighted avg       0.75      0.76      0.74       192
